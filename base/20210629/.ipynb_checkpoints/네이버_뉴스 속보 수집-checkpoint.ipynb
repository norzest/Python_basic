# %% [markdown]
# ### 네이버 뉴스 수집

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def get_page(url):
    html = requests.get(url, headers = headers).text
    soup = BeautifulSoup(html, 'html.parser')
    type06 = soup.find('ul',{'class':'type06_headline'})
    dl = type06.find_all('dl')
    
    return dl

def page_to_items(df, dl, page, dt):
    for item in dl:
        try:
            #이미지 링크 
            img = item.find('dt',{'class':'photo'}).find('img')
            df['img'].append(img['src'])
            #기사 링크  및 제목
            link = item.find('dt',{'class':''}).find('a')
            df['link'].append(link['href'])
            df['title'].append(link.text.replace('\t','').replace('\n','')[1:len(link.text)+1])
            #기사 내용
            content = item.find('dd')
            df['content'].append(content.text.replace('\t','').replace('\n','').split('…')[0])        
            df['date'].append(dt)
            df['page'].append(page)
        except:
            print('No Data')
        
    return df

# %%
from datetime import date

headers = {'User-Agent':'Mozilla/5.0'}
dt = "{:%Y%m%d}".format(date.today())
df = {'img': [], 'link' : [], 'title': [], 'content': [], 'date': [], 'page' : []}

end_page = 2
end_date = 2

for i in range(0, end_date):
    temp_dt = str(int(dt) - i)    
    for j in range(0, end_page):
        page = str(j+1).zfill(3)
        url = 'https://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1=' + page + '&date=' + temp_dt #네이버-뉴스-속보
        dl = get_page(url)
        df = page_to_items(df, dl, page, temp_dt)
        
df = pd.DataFrame(df, columns = ['date', 'page', 'img', 'link', 'title', 'content'])
df.to_csv('df_csv.csv')
pd.read_csv('df_csv.csv')
# Out:
# No Data
#     Unnamed: 0      date  page  \
# 0            0  20210629     1
# 1            1  20210629     1
# 2            2  20210629     1
# 3            3  20210629     1
# 4            4  20210629     1
# 5            5  20210629     1
# 6            6  20210629     1
# 7            7  20210629     1
# 8            8  20210629     1
# 9            9  20210629     2
# 10          10  20210629     2
# 11          11  20210629     2
# 12          12  20210629     2
# 13          13  20210629     2
# 14          14  20210629     2
# 15          15  20210629     2
# 16          16  20210629     2
# 17          17  20210629     2
# 18          18  20210629     2
# 19          19  20210628     1
# 20          20  20210628     1
# 21          21  20210628     1
# 22          22  20210628     1
# 23          23  20210628     1
# 24          24  20210628     1
# 25          25  20210628     1
# 26          26  20210628     1
# 27          27  20210628     1
# 28          28  20210628     1
# 29          29  20210628     2
# 30          30  20210628     2
# 31          31  20210628     2
# 32          32  20210628     2
# 33          33  20210628     2
# 34          34  20210628     2
# 35          35  20210628     2
# 36          36  20210628     2
# 37          37  20210628     2
# 38          38  20210628     2
#
#                                                   img  \
# 0   https://imgnews.pstatic.net/image/origin/031/2...
# 1   https://imgnews.pstatic.net/image/origin/018/2...
# 2   https://imgnews.pstatic.net/image/origin/006/2...
# 3   https://imgnews.pstatic.net/image/origin/015/2...
# 4   https://imgnews.pstatic.net/image/origin/009/2...
# 5   https://imgnews.pstatic.net/image/origin/006/2...
# 15  https://news.naver.com/main/read.nhn?mode=LSD&...
# 16  https://news.naver.com/main/read.nhn?mode=LSD&...
# 17  https://news.naver.com/main/read.nhn?mode=LSD&...
# 18  https://news.naver.com/main/read.nhn?mode=LSD&...
# 19  https://news.naver.com/main/read.nhn?mode=LSD&...
# 20  https://news.naver.com/main/read.nhn?mode=LSD&...
# 21  https://news.naver.com/main/read.nhn?mode=LSD&...
# 22  https://news.naver.com/main/read.nhn?mode=LSD&...
# 23  https://news.naver.com/main/read.nhn?mode=LSD&...
# 24  https://news.naver.com/main/read.nhn?mode=LSD&...
# 25  https://news.naver.com/main/read.nhn?mode=LSD&...
# 26  https://news.naver.com/main/read.nhn?mode=LSD&...
# 27  https://news.naver.com/main/read.nhn?mode=LSD&...
# 28  https://news.naver.com/main/read.nhn?mode=LSD&...
# 29  https://news.naver.com/main/read.nhn?mode=LSD&...
# 30  https://news.naver.com/main/read.nhn?mode=LSD&...
# 31  https://news.naver.com/main/read.nhn?mode=LSD&...
# 32  https://news.naver.com/main/read.nhn?mode=LSD&...
# 33  https://news.naver.com/main/read.nhn?mode=LSD&...
# 34  https://news.naver.com/main/read.nhn?mode=LSD&...
# 35  https://news.naver.com/main/read.nhn?mode=LSD&...
# 36  https://news.naver.com/main/read.nhn?mode=LSD&...
# 37  https://news.naver.com/main/read.nhn?mode=LSD&...
# 38  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                                 title  \
# 0        '눈 마주친 70대 무차별 폭행' 20대 "피해자가 먼저 큰 소리로 역정내"\r
# 1                   檢 '男 아동·청소년 79명 몸캠 유포' 김영준 구속기소\r
# 2                   직설화법 윤석열? 새로운 메시지 없이 모호한 답만 남았다\r
# 3      [마켓인사이트]김태엽 어펄마캐피탈 대표, '어린이 교통안전 릴레이 챌린지' 동참\r
# 4                     박지원 대기업 임원 사위 마약 밀수입 혐의로 재판받아\r
# 5                      윤석열, 정치중립성 훼손에 "원칙에 따라" 동문서답\r
# 6                    결국 깃발 든 윤석열 "정권교체 못하면 역사 앞에 죄"\r
# 7                   HMM, 현대重·대우조선에 초대형 컨테이너선 12척 발주\r
# 8                     카카오게임즈 ‘오딘' 출시…구글·애플 마켓 인기 1위\r
# 9                        ‘멀티 골’ 허용준, K리그2 18라운드 MVP\r
# 10                       [MD포토] 김동수 코치, '(이)영빈아 힘내'\r
# 11   [POP초점]에드 시런, BTS 신곡 컬래버→열혈 스포중.."Permission ...
# 12                            인천, 미드필더 정혁 자유계약으로 영입\r
# 13                        안철수, '곽씨네 LP바' 찾았다…30일 방송\r
# 14                                        신규확진 595명\r
# 15                            원/달러 환율 약보합 마감…관망세 지속\r
# 16                         6차 전원회의 참석하는 박준식 최저임금위원장\r
# 17                               '재밍 건'으로 드론 비행 멈추기\r
# 18                                  최저임금위 '고민하는 노사'\r
# 19         BRITAIN TENNIS WIMBLEDON GRAND SLAM 2021\r
# 20         BRITAIN TENNIS WIMBLEDON GRAND SLAM 2021\r
# 21         BRITAIN TENNIS WIMBLEDON GRAND SLAM 2021\r
# 22         BRITAIN TENNIS WIMBLEDON GRAND SLAM 2021\r
# 23           Denmark Croatia Spain Euro 2020 Soccer\r
# 24                 中 CATL, 테슬라 배터리 공급 계약 2025년까지 연장\r
# 25                    DENMARK SOCCER UEFA EURO 2020\r
# 26                    DENMARK SOCCER UEFA EURO 2020\r
# 27                 Germany England Euro 2020 Soccer\r
# 28                    DENMARK SOCCER UEFA EURO 2020\r
# 29     '신박한 정리' 민우혁♥이세미, 4대가 모여 사는 집 공개→정리까지 말끔(종합)\r
# 30       '동상이몽2' 구재이, "프랑스 대학 교수 남편 때문에 프랑스서 신혼 보내"\r
# 31                        구재이 “남편 코디 내가 직접, 면바지 로망”\r
# 32                                 런던 남부 기차역 부근서 큰불\r
# 33       ‘골프왕’ 골프신동들 등장에 멤버들 동공지진→필드 댄스대결 '폭소' [종합]\r
# 34             장영란, 프로 다이어터 다 됐네 "하루 마무리 20층 계단오르기"\r
# 35   모델 구재이 "佛대학교수 남편♥이 3주마다 韓날아와‥출산후 몸매도 회복" ('동상...
# 36              두산 전력분석원 외에도 수도권 팀 코치까지 코로나19 확진 판정\r
# 37                       이탈리아, 전국 대부분서 실외 마스크 의무 해제\r
# 38   'MBC 이즈백' 이순재, '야동순재' 대본 첫 반응 "이걸 꼭 해야겠어?" [종...
#
#                                               content
# 0   자신과 눈이 마주쳤다는 이유만으로 70대 남성을 무차별 폭행한 20대 남성이 첫 재...
# 1   [이데일리 남궁민관 기자] 검찰이 남성 아동·청소년 79명을 상대로 성착취물을 제작...
# 2   윤석열 전 검찰총장이 첫 기자회견에 나선 가운데 기존에 알려진 내용과 다른 메시지는...
# 3   ≪이 기사는 06월29일(15:55) 자본시장의 혜안 ‘마켓인사이트’ 에 게재된 기...
# 4   국내 대기업 임원으로 재직 중인 박지원 국가정보원장의 사위 A씨가 미국에서 마약류를...
# 5   윤석열 전 검찰총장이 대선출마 선언을 하며 정권교체에 앞장서겠다고 밝혔다. 그러나 ...
# 6   [[the300](종합)] 마침내 윤석열 전 검찰총장이 대권 도전을 공식화하면서 '...
# 7   HMM(011200) 이 3년만에 초대형 컨테이너선 20척을 모두 투입한데 이어, ...
# 8   카카오게임즈는 29일 모바일 다중접속온라인역할수행게임(MMORPG) ‘오딘: 발할라...
# 9   [OSEN=우충원 기자] 김천 허용준이 ‘하나원큐 K리그2 2021’ 18라운드 M...
# 10  [마이데일리 = 송일섭 기자] 29일 오후 서울 잠실야구장에서 진행될 예정이었던 '...
# 11  [헤럴드POP=박서연 기자]영국 싱어송라이터 에드 시런(Ed Sheeran)이 그룹...
# 12  [스포츠경향] 정혁. 인천 유나이티드 제공인천 유나이티드가 베테랑이 된 미드필더 정...
# 13  [마이데일리 = 박윤진 기자] 케이블채널 tvN '곽씨네 LP바'에 국민의당 안철수...
# 14  (서울=연합뉴스) 박동주 기자 = 29일 오후 서울 중구 서울역 광장에 마련된 신종...
# 15  (서울=연합뉴스) 김연숙 기자 = 29일 원/달러 환율이 소폭 하락했다. 이날 서울...
# 16  (세종=연합뉴스) 김주형 기자 = 박준식 최저임금위원회 위원장이 29일 세종시 정부...
# 17  (서울=연합뉴스) 홍해인 기자 = 29일 오후 서울 송파구 잠실종합운동장에서 열린 ...
# 18  (세종=연합뉴스) 김주형 기자 = 29일 오후 세종시 정부세종청사 최저임금위원회 회...
# 19  Wimbledon Championships 2021 Jack Draper of Br...
# 20  Wimbledon Championships 2021 Frances Tiafoe of...
# 21  Wimbledon Championships 2021 Novak Djokovic of...
# 22  Wimbledon Championships 2021 Novak Djokovic of...
# 23  Spain's manager Luis Enrique looks on prior to...
# 24  (서울=뉴스1) 최서윤 기자 = 중국 전기차 배터리업체 CATL이 미국 전기차업체 ...
# 25  Round of 16 Croatia vs Spain General view insi...
# 26  Round of 16 Croatia vs Spain Spain's head coac...
# 27  Elephant cow Yashoda holds up the flag of Germ...
# 28  Round of 16 Croatia vs Spain Luka Modric of Cr...
# 29  [헤럴드POP=임채령 기자] 4대가 모여사는 민우혁과 이세미 집이 공개됐다. 28일...
# 30  [SBS연예뉴스 | 김효정 에디터] 구재이가 결혼 후 프랑스로 간 이유를 밝혔다. ...
# 31  구재이 “남편 코디 내가 직접, 면바지 로망” 배우 구재이가 남편의 코디를 담당하고...
# 32  (런던=연합뉴스) 최윤정 특파원 = 영국 런던 남쪽의 한 기차역 부근에서 28일(현...
# 33  골프왕 멤버들이 골프신동들과 나이를 초월한 골프 맞대결을 펼친 가운데 2:3으로 최...
# 34  [헤럴드POP=이미지 기자] 장영란이 다이어터로서의 일상을 공유했다. 방송인 장영란...
# 35  [OSEN=김수형 기자] ‘동상이몽2’에서 구재이가 출연해 남편과 롱디 스토리부터,...
# 36  [스포츠경향] 잠실야구장. 연합뉴스프로야구 수도권 구단에서 신종 코로나바이러스 감염...
# 37  (로마=연합뉴스) 전성훈 특파원 = 이탈리아가 28일(현지시간)부터 전국 거의 모든...
# 38  '야동순재' 탄생 비화가 공개됐다. 28일 오후 방송된 특집 프로그램 'MBC 이즈...

# %%
df = {'page' : '2', 'date' : '20210607'}

df.update({'page' : '3', 'date' : '20210608'})
df
# Out:
# {'page': '3', 'date': '20210608'}
