# %% [markdown]
# ### 유튜브 데이터 수집
# 1. 화면에서 검색어를 입력
# 2. selenium으로 키워드 검색
#     - source => soup
# 3. 검색 결과를 수집
#     - "h3", {"class":"title-and-badge style-scope ytd-video-renderer"}
#     - video type
#         + 채널명, 영상제목, 영상url, 조회수, 영상등록날짜
#         - video_df
#     - "div", {"class":"style-scope ytd-playlist-renderer"}
#     - playlist type
#         + 채널명, 재생목록제목, 재생목록url
#         - playlist_df

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

driver = webdriver.Chrome("c:/python/chromedriver")

# %%
url  = "https://www.youtube.com/results?search_query=%ED%8C%8C%EC%9D%B4%EC%8D%AC+%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D"
driver.get(url)

# %%
source = driver.page_source

# %%
soup = BeautifulSoup(source, "html.parser")

# %%
video_type = soup.find_all("div", {"id":"dismissible"})

# %%
playlist_type = soup.find_all("div", {"class":"style-scope ytd-playlist-renderer"})

# %%
total_vd = []

for i,item in enumerate(video_type):
        ch_name = item.find("tp-yt-paper-tooltip", {"class": "style-scope ytd-channel-name"}).text.replace("\n","").strip()
        print("ch_name = ", ch_name)
        title = item.find("yt-formatted-string",{"class":"style-scope ytd-video-renderer"}).text
        print("title = ", title)
        link = item.find("a",{"class":"yt-simple-endpoint style-scope ytd-video-renderer"})["href"]
        print("link = {}".format("youtube.com/"+link,end=""))
        hit = item.find_all("span",{"class" : "style-scope ytd-video-meta-block"})[0].text
        print("hit = ", hit)
        regdate = item.find_all("span",{"class" : "style-scope ytd-video-meta-block"})[1].text
        print("-"*30)
        total_vd.append([ch_name, title, link, hit, regdate])
# Out:
# ch_name =  GongbroDesk
# title =  파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립, 판다스)
# link = youtube.com/watch?v=8_VWnRvbGPs
# hit =  조회수 1.7만회
# ------------------------------
# ch_name =  데이터 스테이션
# title =  파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pandas) #Python #파이썬 #Pandas
# link = youtube.com/watch?v=3-iwY0_u0VA
# hit =  조회수 3.9천회
# ------------------------------
# ch_name =  Visualising Korea
# title =  무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 Python (파이썬) 비교
# link = youtube.com/watch?v=1e2IjkDYE_8
# hit =  조회수 2.3만회
# ------------------------------
# ch_name =  todaycode오늘코드
# title =  [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개, cheat sheet 보고 데이터프레임 만들어보기 튜토리얼
# link = youtube.com/watch?v=lspu830SzC8
# hit =  조회수 3만회
# ------------------------------
# ch_name =  테디노트
# title =  25분만에 끝내는 데이터분석, 머신러닝을 위한 기본 파이썬
# link = youtube.com/watch?v=JoL3ACNDs-I
# hit =  조회수 9.4천회
# ------------------------------
# ch_name =  todaycode오늘코드
# title =  [1/5] 파이썬 데이터 분석 - 전국 도시 공원 표준 데이터 불러오기, 요약하기
# link = youtube.com/watch?v=uJ6QO6jLBWA
# hit =  조회수 1.2만회
# ------------------------------
# ch_name =  Data Scientist이지영
# title =  [통계, 파이썬] 데이터분석 능력 기르기 1. 이건 알고 시작하자.
# link = youtube.com/watch?v=Dfpi4pAzn78
# hit =  조회수 7.6천회
# ------------------------------
# ch_name =  Data Scientist이지영
# title =  [통계, 파이썬] 데이터분석 능력 기르기 2. 빅데이터의 저주, 파이썬으로 구현하기
# link = youtube.com/watch?v=Ax5ENEciYbE
# hit =  조회수 2.5천회
# ------------------------------
# ch_name =  데이터 스테이션
# title =  Python Pandas 실무 데이터 분석 1탄 (Series / Dataframe 구조) #Python #파이썬 #Pandas
# link = youtube.com/watch?v=q4UFSZPjLyo
# hit =  조회수 6.4천회
# ------------------------------
# ch_name =  꽃부리 AI With SJ
# title =  머신러닝, 데이터분석 공부 고민만 하는 분께 l 파이썬 공부 이유 l 머신러닝 공부 순서
# link = youtube.com/watch?v=irenjQzqQsw
# hit =  조회수 5.9천회
# ------------------------------
# ch_name =  매일경제 에브리데이
# title =  데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 KING은 누구?/현직자인터뷰/카카오모빌리티/취업꿀팁
# link = youtube.com/watch?v=luA8-_BHWRE
# hit =  조회수 8.1천회
# ------------------------------
# ch_name =  매일경제 에브리데이
# title =  데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 KING은 누구?/현직자인터뷰/카카오모빌리티/취업꿀팁
# link = youtube.com/watch?v=luA8-_BHWRE
# hit =  조회수 8.1천회
# ------------------------------
# ch_name =  Tokuni TV
# title =  [경험] 파이썬 주식자동매매 프로그램을 만들고도 이용하지 않는 이유 ((실전 자동매매 영상 포함))
# link = youtube.com/watch?v=s4S_aUeW0z0
# hit =  조회수 2.5만회
# ------------------------------
# ch_name =  흑우스토리
# title =  자동매매 프로그램을 완성했지만 사용을 포기한 이유
# link = youtube.com/watch?v=97h-bpJPxM4
# hit =  조회수 12만회
# ------------------------------
# ch_name =  리뷰BRO
# title =  빅데이터 2년공부하고 다른걸로 취업했다! 빅데이터와 취업 리뷰! [ 빅데이터 분석가 / 빅데이터 전문가 ]
# link = youtube.com/watch?v=QtcWFDZGN8M
# hit =  조회수 11만회
# ------------------------------
# ch_name =  더블리
# title =  [Chapter #2] 2.파이썬 데이터 읽기, 이렇게 쉽게 가능해? 판다스(Pandas)의 등장! 사용하기전에 알면 좋은 방법론! (부동산 데이터 제공!)
# link = youtube.com/watch?v=RMaZ_uWfrdw
# hit =  조회수 3천회
# ------------------------------
# ch_name =  파이썬멘토 조인석
# title =  파이썬 데이터 분석 실습 - 한국 코로나 캐글 데이터 활용 (South Korea COVID-19/Corona Python Data Analysis on Kaggle)
# link = youtube.com/watch?v=JchtSO8YX2U
# hit =  조회수 1.8천회
# ------------------------------
# ch_name =  todaycode오늘코드
# title =  [1/7] Python, Pandas,  folium으로 스타벅스, 이디야 매장 위치 분석하기
# link = youtube.com/watch?v=PR1WeCdFWvg
# hit =  조회수 1.7만회
# ------------------------------
# ch_name =  러닝스푼즈
# title =  포항공대에서 화장품 대기업 그리고 데이터 분석가로의 커리어 | 러닝스푼즈
# link = youtube.com/watch?v=I_2EIEF4p3s
# hit =  조회수 2.5만회
# ------------------------------
# ch_name =  메모밍 채널 ( Channel Memoming )
# title =  [파이썬] 데이터 분석을 위한 파이썬 [08] Pandas (Python for Data Analysis)
# link = youtube.com/watch?v=19oPYr6d5IY
# hit =  조회수 4.7천회
# ------------------------------

# %%
total_pl = []

for i,item in enumerate(playlist_type):
        ch_name = item.find("tp-yt-paper-tooltip", {"class": "style-scope ytd-channel-name"}).text.replace("\n","").strip()
        print("ch_name = ", ch_name)
        title = item.find("h3", {"class": "style-scope ytd-playlist-renderer"}).text.replace("\n","").strip()
        print("title = ", title)
        link = item.find("a",{"class":"yt-simple-endpoint style-scope ytd-playlist-renderer"})["href"]
        print("link = youtube.com{}".format(link))
        print("-"*30)
        total_pl.append([ch_name, title, link])
# Out:
# ch_name =  한빛미디어
# title =  이것이 데이터 분석이다 with 파이썬
# link = youtube.com/watch?v=K0YPltIT7jc&list=PLVsNizTWUw7FmLj3IMECoauQ_-DUbNF0M
# ------------------------------
# ch_name =  메모밍 채널 ( Channel Memoming )
# title =  [Python] 데이터분석을 위한 파이썬
# link = youtube.com/watch?v=XjfUcQk8PiE&list=PL-QFFQeuiKKsvRLFeOgu594EmqdM-9ZBI
# ------------------------------
# ch_name =  리송스쿨
# title =  왕초보들을 위한 데이터분석 강의! 모두의 데이터분석 with 파이썬
# link = youtube.com/watch?v=9-_UWTPRlQI&list=PLZOZh8ZFHaxAZAdCK_8Ae54upoYkWqB25
# ------------------------------
# ch_name =  코딩네이터
# title =  파이썬을 활용한 DART 재무제표 데이터 수집과 분석
# link = youtube.com/watch?v=KPXtTblimLc&list=PLtZZeSmsOAKrBP-5xx8kY5hGaDWvXv_aK
# ------------------------------
# ch_name =  Flipped learning
# title =  python-data-analysis
# link = youtube.com/watch?v=nxSVZVVfMxM&list=PLWO_EXTnt3sPmlgCeHAiHwaAFwmmusGp6
# ------------------------------

# %%
import pandas as pd

# %%
vd_df = pd.DataFrame(total_vd,columns=["ch_name", "title", "link", "hit", "regdate"])
vd_df
# Out:
#                         ch_name  \
# 0                   GongbroDesk
# 1                      데이터 스테이션
# 2             Visualising Korea
# 3                 todaycode오늘코드
# 4                          테디노트
# 5                 todaycode오늘코드
# 6             Data Scientist이지영
# 7             Data Scientist이지영
# 8                      데이터 스테이션
# 9                꽃부리 AI With SJ
# 10                   매일경제 에브리데이
# 11                   매일경제 에브리데이
# 12                    Tokuni TV
# 13                        흑우스토리
# 14                        리뷰BRO
# 15                          더블리
# 16                    파이썬멘토 조인석
# 17                todaycode오늘코드
# 18                        러닝스푼즈
# 19  메모밍 채널 ( Channel Memoming )
#
#                                                 title                  link  \
# 0   파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...  /watch?v=8_VWnRvbGPs
# 1   파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...  /watch?v=3-iwY0_u0VA
# 2   무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 ...  /watch?v=1e2IjkDYE_8
# 3   [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개...  /watch?v=lspu830SzC8
# 4                    25분만에 끝내는 데이터분석, 머신러닝을 위한 기본 파이썬  /watch?v=JoL3ACNDs-I
# 5       [1/5] 파이썬 데이터 분석 - 전국 도시 공원 표준 데이터 불러오기, 요약하기  /watch?v=uJ6QO6jLBWA
# 6               [통계, 파이썬] 데이터분석 능력 기르기 1. 이건 알고 시작하자.  /watch?v=Dfpi4pAzn78
# 7      [통계, 파이썬] 데이터분석 능력 기르기 2. 빅데이터의 저주, 파이썬으로 구현하기  /watch?v=Ax5ENEciYbE
# 8   Python Pandas 실무 데이터 분석 1탄 (Series / Dataframe...  /watch?v=q4UFSZPjLyo
# 9   머신러닝, 데이터분석 공부 고민만 하는 분께 l 파이썬 공부 이유 l 머신러닝 공부 순서  /watch?v=irenjQzqQsw
# 10  데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 K...  /watch?v=luA8-_BHWRE
# 11  데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 K...  /watch?v=luA8-_BHWRE
# 12  [경험] 파이썬 주식자동매매 프로그램을 만들고도 이용하지 않는 이유 ((실전 자동매...  /watch?v=s4S_aUeW0z0
# 13                        자동매매 프로그램을 완성했지만 사용을 포기한 이유  /watch?v=97h-bpJPxM4
# 14  빅데이터 2년공부하고 다른걸로 취업했다! 빅데이터와 취업 리뷰! [ 빅데이터 분석가...  /watch?v=QtcWFDZGN8M
# 15  [Chapter #2] 2.파이썬 데이터 읽기, 이렇게 쉽게 가능해? 판다스(Pan...  /watch?v=RMaZ_uWfrdw
# 16  파이썬 데이터 분석 실습 - 한국 코로나 캐글 데이터 활용 (South Korea ...  /watch?v=JchtSO8YX2U
# 17  [1/7] Python, Pandas,  folium으로 스타벅스, 이디야 매장 위...  /watch?v=PR1WeCdFWvg
# 18           포항공대에서 화장품 대기업 그리고 데이터 분석가로의 커리어 | 러닝스푼즈  /watch?v=I_2EIEF4p3s
# 19  [파이썬] 데이터 분석을 위한 파이썬 [08] Pandas (Python for D...  /watch?v=19oPYr6d5IY
#
#           hit regdate
# 0   조회수 1.7만회   6개월 전
# 1   조회수 3.9천회   4개월 전
# 2   조회수 2.3만회  11개월 전
# 3     조회수 3만회    2년 전
# 4   조회수 9.4천회    1년 전
# 5   조회수 1.2만회    2년 전
# 6   조회수 7.6천회  11개월 전
# 7   조회수 2.5천회  11개월 전
# 8   조회수 6.4천회    1년 전
# 9   조회수 5.9천회   4개월 전
# 10  조회수 8.1천회   3개월 전
# 11  조회수 8.1천회   3개월 전
# 12  조회수 2.5만회   6개월 전
# 13   조회수 12만회    1년 전
# 14   조회수 11만회    2년 전
# 15    조회수 3천회    1년 전
# 16  조회수 1.8천회    1년 전
# 17  조회수 1.7만회    2년 전
# 18  조회수 2.5만회    1년 전
# 19  조회수 4.7천회    2년 전

# %%
pl_df = pd.DataFrame(total_pl,columns=["ch_name", "title", "link"])
pl_df
# Out:
#                        ch_name                                  title  \
# 0                        한빛미디어                  이것이 데이터 분석이다 with 파이썬
# 1  메모밍 채널 ( Channel Memoming )                 [Python] 데이터분석을 위한 파이썬
# 2                         리송스쿨  왕초보들을 위한 데이터분석 강의! 모두의 데이터분석 with 파이썬
# 3                        코딩네이터          파이썬을 활용한 DART 재무제표 데이터 수집과 분석
# 4             Flipped learning                   python-data-analysis
#
#                                                 link
# 0  /watch?v=K0YPltIT7jc&list=PLVsNizTWUw7FmLj3IME...
# 1  /watch?v=XjfUcQk8PiE&list=PL-QFFQeuiKKsvRLFeOg...
# 2  /watch?v=9-_UWTPRlQI&list=PLZOZh8ZFHaxAZAdCK_8...
# 3  /watch?v=KPXtTblimLc&list=PLtZZeSmsOAKrBP-5xx8...
# 4  /watch?v=nxSVZVVfMxM&list=PLWO_EXTnt3sPmlgCeHA...
