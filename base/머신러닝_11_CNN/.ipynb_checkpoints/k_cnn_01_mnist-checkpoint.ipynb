# %%
###############################
# 분류 CNN 모델링
###############################
import tensorflow.keras as keras
from tensorflow.keras import models, layers

def CNN(W,H,C , Nout):
        model = models.Sequential()
        model.add( #TODO  
        
        
        )
        model.add(layers. #TODO   ))
        model.add(layers. #TODO   ))
        model.add(layers.#TODO   )
        model.add(layers#TODO   ))
        model.add(layers.Dense(128, activation='relu'))
        model.add(layers.Dropout(0.5))
        model.add(layers.Dense(#TODO  )

        model.compile(loss=keras.losses. #TODO   ,
                      optimizer='rmsprop',
                      metrics=['acc'])
        return model;

# %%
##############################################
# Data
##############################################
from tensorflow.keras import datasets  # mnist
from tensorflow.keras.utils import to_categorical  # to_categorical

def Data_func():
    (X_train, y_train), (X_test, y_test) = datasets.#TODO  
    """ 이미지 데이터 X ,  0~9까지 붙인 이름표를 Y   
        70,000개의 데이터 중 60,000개를 학습 데이터로,  10,000개를 테스트 데이터로 읽어옵니다. 
    """

    Y_train =  #TODO  
    Y_test = #TODO  
    """원-핫 인코딩을 위해 케라스의 np_utils 의 to_categorical() 함수를 사용
     0 ~ 9까지의 정수 값을 갖는 형태가 아닌 0 이나 1로 이뤄진 벡터로 수정 
     만약에 '3' 이라는 숫자이라면 [0, 0, 1, 0, 0, 0, 0, 0, 0]으로 변환 
    """

    L, W, H = X_train.shape
    print(L, W, H)  # 60000 28 28

    X_train = X_train.#TODO  (60000, W, H,-1)
    X_test = X_test.#TODO  (10000,W, H,-1)

    X_train = #TODO  / 255.0
    X_test = X_test / 255.0

    return (X_train, Y_train), (X_test, Y_test)

# %%
###########################
# 학습 효과 분석
###########################
import matplotlib.pyplot as plt
###############################
# 분류 CNN 학습 및 테스트
###############################
def main():
    number_of_class = 10
    Nout = number_of_class

    batch_size = 128
    epochs = 10

    (X_train, Y_train), (X_test, Y_test) = #TODO  ()
    model = #TODO  (28,28,1,           Nout)
               #width, hight, color

    history = model.#TODO  (X_train, Y_train,
              batch_size=batch_size,
              #TODO  =epochs,
              #TODO  t=0.2)

    score = model.#TODO  (X_test, Y_test)
    print()
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

    history = history.history

    """정확도 변화 추이  그래프"""
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Verification'], loc=0)
    plt.show()

    """Cost/Loss  변화 추이 그래프"""
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Verification'], loc=0)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# 60000 28 28
# Epoch 1/10
# 375/375 [==============================] - 62s 163ms/step - loss: 0.2495 - accuracy: 0.9243 - val_loss: 0.0697 - val_accuracy: 0.9799
# Epoch 2/10
# 375/375 [==============================] - 60s 161ms/step - loss: 0.0888 - accuracy: 0.9736 - val_loss: 0.0485 - val_accuracy: 0.9861
# Epoch 3/10
# 375/375 [==============================] - 61s 164ms/step - loss: 0.0673 - accuracy: 0.9801 - val_loss: 0.0445 - val_accuracy: 0.9873
# Epoch 4/10
# 375/375 [==============================] - 61s 164ms/step - loss: 0.0546 - accuracy: 0.9836 - val_loss: 0.0497 - val_accuracy: 0.9865
# Epoch 5/10
# 375/375 [==============================] - 63s 168ms/step - loss: 0.0482 - accuracy: 0.9856 - val_loss: 0.0415 - val_accuracy: 0.9882
# Epoch 6/10
# 375/375 [==============================] - 63s 167ms/step - loss: 0.0462 - accuracy: 0.9864 - val_loss: 0.0454 - val_accuracy: 0.9873
# Epoch 7/10
# ...
