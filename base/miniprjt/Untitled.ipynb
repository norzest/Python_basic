# %%
import pandas as pd

teenager = pd.read_csv("data/crime_teenager.csv", encoding='cp949')
night = pd.read_csv("data/nightlife_crime.csv", encoding='cp949')

# %%
teenager
# Out:
#    location  murder  robbery  forcible_rape  thief  violence
# 0      중  부       0        0              1     44        42
# 1      종  로       0        3              4     34        57
# 2       남대문       0        0              0     43         4
# 3       서대문       0        4              5    142       103
# 4      혜  화       0        2              2     38        29
# 5      용  산       0        4              4     56        70
# 6      성  북       0        1              5     69        99
# 7       동대문       1        1              5    126        76
# 8      마  포       0        0             13    156       164
# 9       영등포       0        0              6    119       118
# 10     성  동       0        0             11    105        73
# 11     동  작       1        3              6    107        65
# 12     광  진       0        0             29    155       153
# 13     서  부       0        0              4    120       131
# ...

# %%
night
# Out:
#    region  pub  karaoke  tot_nightlife  murder  robbery  forcible_rape  thef  \
# 0      강남  283      354            637       0        6             19   140
# 1      강동  146      106            252       0        3              6   193
# 2      강북   79      128            207       0        0              9   166
# 3      강서  113      167            280       0        3              9   273
# 4      관악  223       99            322       0        2             14   170
# 5      광진   19       91            110       0        0             29   155
# 6      구로   38      110            148       0        1              3   157
# 7      금천   60       82            142       0        0              7   146
# 8      노원   30       57             87       0        6             14   227
# 9      도봉   21       55             76       0        6             21   126
# 10    동대문   88      115            203       1        1              5   126
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.pairplot(night)
plt.show()

# %%
htmap = sns.heatmap(data = night.corr(), annot=True,  fmt = '.2f', linewidths=.5, cmap='Blues')
htmap

# %%
df = night.corr(method='pearson')
df
# Out:
#                         pub   karaoke  tot_nightlife    murder   robbery  \
# pub                1.000000  0.645022       0.922502 -0.166262  0.158527
# karaoke            0.645022  1.000000       0.889996 -0.161529  0.113546
# tot_nightlife      0.922502  0.889996       1.000000 -0.180798  0.151945
# murder            -0.166262 -0.161529      -0.180798  1.000000 -0.162691
# robbery            0.158527  0.113546       0.151945 -0.162691  1.000000
# forcible_rape     -0.113338  0.032942      -0.050988 -0.194361  0.108991
# thef              -0.151376  0.041039      -0.069595 -0.072016 -0.018253
# violence          -0.050001  0.118708       0.030126 -0.184772  0.089853
# murder_tot         0.072228  0.205042       0.146668  0.197589 -0.083264
# robbery_Tot        0.323537  0.674551       0.533779  0.022519 -0.001794
# forcible_rape_Tot  0.335075  0.389660       0.396760  0.073777 -0.017104
# thef_tot           0.305869  0.336648       0.352556  0.002306 -0.077351
# ...

# %%
sns.pairplot(teenager)
plt.show()
