# %% [markdown]
# ### ( 1. 데이터 검색 후 검색결과 html 받기 )

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome("c:/jswoo/chromedriver")

#search_word = input("검색어? ")
search_word = "파이썬 데이터분석"

url = "https://www.youtube.com/results?search_query="+ search_word

print(" 1. 유튜브 접속 및 키워드 검색!!!!!!")
driver.get(url)
time.sleep(0.5)
# Out:
#  1. 유튜브 접속 및 키워드 검색!!!!!!

# %%
print(" 2. Page Down !")

from selenium.webdriver.common.keys import Keys

body = driver.find_element_by_tag_name("body")

for page_down in range(1,10):
    print("page_down = ", page_down)
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
# Out:
#  2. Page Down !
# page_down =  1
# page_down =  2
# page_down =  3
# page_down =  4
# page_down =  5
# page_down =  6
# page_down =  7
# page_down =  8
# page_down =  9

# %%
print(" 3. 페이지 html BeautifulSoup 적용 !!!!!!")
from bs4 import BeautifulSoup

#html = driver.page_source  # requests.get 

soup = BeautifulSoup(driver.page_source, "html.parser") # soup
print(" BeautifulSoup 완료!! ")
# Out:
#  3. 페이지 html BeautifulSoup 적용 !!!!!!
#  BeautifulSoup 완료!!

# %%
youtube_base_url = "https://www.youtube.com/"

# 개별 영상 타입 추출 

print(" 4. 개별 영상 타입 추출   !!!!!!")

#3 class="title-and-badge style-scope ytd-video-renderer">
lis = soup.find_all("h3",{"class":"title-and-badge style-scope ytd-video-renderer"})

video_list = []

for video in lis:
    data = video.find("a")["aria-label"]

    len = data.find("게시자")    
    item = data[len:].split()

    channel = item[1]

    title = data[:len-1]
    
    video_url = youtube_base_url+video.find("a")["href"]

    views_count =item[-1]
    upload_date = item[2]+item[3]
   
    video_list.append([channel, title, video_url, views_count, upload_date])
    
# 추출한 list로 dataframe 만들기 
    
import pandas as pd
df_video_item = pd.DataFrame(video_list)

# # 컬럼 만들기
df_video_item.columns = ["채널명","영상제목","영상url","조회수","영상등록날짜"]

print(" 5. 개별영상 타입 완료 = ", df_video_item.shape)

# 재생목록 보기 타입

print(" 6. 재생목록 타입 추출   !!!!!!")

#lis = soup.find_all("h3",{"class":"title-and-badge style-scope ytd-video-renderer"})
lis = soup.find_all("div",{"class":"style-scope ytd-playlist-renderer"})

video_playlist = []

for video in lis:
    channel = video.find("div",{"id":"tooltip"}).text.strip()
    title = video.find("span")["title"]
    play_link = youtube_base_url+video.find("a")["href"]
    
#     print(channel, " * ", title, " * ", play_link )    
    video_playlist.append([channel, title, play_link])
    
# 추출한 list로 dataframe 만들기 
df_video_playlist = pd.DataFrame(video_playlist)

# 컬럼 만들기
df_video_playlist.columns = ["채널명","재생목록제목","재생목록url"]


# 재생목록 영상수 
video_count = soup.find_all("yt-formatted-string",{"class":"style-scope ytd-thumbnail-overlay-side-panel-renderer"})

video_count_list= []
for item in video_count:
    video_count_list.append(item.text)
video_count_list

# 영상수 컬럼 추가 
df_video_playlist["영상수"] = video_count_list

print(" 7. 재생목록  타입 완료 = ", df_video_playlist.shape)
# Out:
#  4. 개별 영상 타입 추출   !!!!!!
#  5. 개별영상 타입 완료 =  (20, 5)
#  6. 재생목록 타입 추출   !!!!!!
#  7. 재생목록  타입 완료 =  (4, 4)

# %%
df_video_item.head(3)
# Out:
#              채널명                                               영상제목  \
# 0    GongbroDesk  파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...
# 1            데이터  파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...
# 2  todaycode오늘코드  [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개...
#
#                                           영상url      조회수   영상등록날짜
# 0  https://www.youtube.com//watch?v=8_VWnRvbGPs  17,732회     6개월전
# 1  https://www.youtube.com//watch?v=3-iwY0_u0VA   3,914회  스테이션4개월
# 2  https://www.youtube.com//watch?v=lspu830SzC8  30,867회      2년전

# %%
df_video_playlist.head(3)
# Out:
#                            채널명                                 재생목록제목  \
# 0                        한빛미디어                  이것이 데이터 분석이다 with 파이썬
# 1  메모밍 채널 ( Channel Memoming )                 [Python] 데이터분석을 위한 파이썬
# 2                         리송스쿨  왕초보들을 위한 데이터분석 강의! 모두의 데이터분석 with 파이썬
#
#                                              재생목록url 영상수
# 0  https://www.youtube.com//watch?v=K0YPltIT7jc&l...  21
# 1  https://www.youtube.com//watch?v=XjfUcQk8PiE&l...   9
# 2  https://www.youtube.com//watch?v=9-_UWTPRlQI&l...  18

# %% [markdown]
# ### ( type 2 )

# %%
video_list = soup.select('a#video-title')

item = video_list[0]

print("item = ", item.get("aria-label"))
print("link = ", item.get("href"))
# Out:
# item =  파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립, 판다스) 게시자: GongbroDesk 5개월 전 10시간 19분 조회수 13,891회
# link =  /watch?v=8_VWnRvbGPs

# %% [markdown]
# ## ( type 3 )

# %%
# 영상 제목 list
title = soup.select(".title-and-badge > #video-title")
title_list = [item["title"] for item in title]

# 채널명 list
channel_name = soup.select("#channel-info #text > a")
channel_list = [item.text for item in channel_name]

# 영상 url list
youtube_url = "https://www.youtube.com/channel"
url_list = [youtube_url + item["href"] for item in channel_name]

# %%
import pandas as pd 

pd.DataFrame({"제목":title_list, 
            "채널명": channel_list,
              "영상url": url_list})
# Out:
#                                                    제목                채널명  \
# 0   파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...        GongbroDesk
# 1   파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...           데이터 스테이션
# 2   [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개...      todaycode오늘코드
# 3   무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 ...  Visualising Korea
# 4       [1/5] 파이썬 데이터 분석 - 전국 도시 공원 표준 데이터 불러오기, 요약하기      todaycode오늘코드
# 5                    25분만에 끝내는 데이터분석, 머신러닝을 위한 기본 파이썬               테디노트
# 6               [통계, 파이썬] 데이터분석 능력 기르기 1. 이건 알고 시작하자.  Data Scientist이지영
# 7      [통계, 파이썬] 데이터분석 능력 기르기 2. 빅데이터의 저주, 파이썬으로 구현하기  Data Scientist이지영
# 8   데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 K...         매일경제 에브리데이
# 9                                 데이터 AI 사이언티스트 하지마세요           AI Holic
# 10  빅데이터 2년공부하고 다른걸로 취업했다! 빅데이터와 취업 리뷰! [ 빅데이터 분석가...              리뷰BRO
# 11  파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 ...               나도코딩
# 12  [Chapter #2] 2.파이썬 데이터 읽기, 이렇게 쉽게 가능해? 판다스(Pan...                더블리
# 13            Numpy의 기본 사용법 [ Python 데이터 분석과 이미지 처리 ]                동빈나
# 14  머신러닝, 데이터분석 공부 고민만 하는 분께 l 파이썬 공부 이유 l 머신러닝 공부 순서     꽃부리 AI With SJ
# 15  Python Pandas 실무 데이터 분석 1탄 (Series / Dataframe...           데이터 스테이션
# 16                [비전공자를 위한] 파이썬 주식데이터 분석 입문 강의 PART1              사이다경제
# 17  실제 엑셀 데이터 전처리 쉽게하기! (python / data / pandas) #...           데이터 스테이션
# 18  [1/7] Python, Pandas,  folium으로 스타벅스, 이디야 매장 위...      todaycode오늘코드
# 19            파이썬으로 일상의 데이터를 분석하는 법! 코로나 데이터를 분석해 봐요!      온라인 코딩 스쿨 코드잇
#
#                                                 영상url
# 0   https://www.youtube.com/channel/channel/UCo82I...
# 1   https://www.youtube.com/channel/channel/UCyc4x...
# 2   https://www.youtube.com/channel/channel/UCLR3s...
# 3   https://www.youtube.com/channel/channel/UCbBev...
# 4   https://www.youtube.com/channel/channel/UCLR3s...
# 5   https://www.youtube.com/channel/channel/UCt2wA...
# 6   https://www.youtube.com/channel/channel/UC2Bre...
# 7   https://www.youtube.com/channel/channel/UC2Bre...
# 8   https://www.youtube.com/channel/channel/UCIipm...
# 9     https://www.youtube.com/channel/user/ChrissSong
# 10  https://www.youtube.com/channel/channel/UC_fO2...
# 11  https://www.youtube.com/channel/channel/UC7iAO...
# 12  https://www.youtube.com/channel/channel/UCH4kA...
# 13  https://www.youtube.com/channel/channel/UChflh...
# 14  https://www.youtube.com/channel/channel/UCUdyx...
# 15  https://www.youtube.com/channel/channel/UCyc4x...
# 16  https://www.youtube.com/channel/channel/UC-if2...
# 17  https://www.youtube.com/channel/channel/UCyc4x...
# 18  https://www.youtube.com/channel/channel/UCLR3s...
# 19  https://www.youtube.com/channel/channel/UCCM79...

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

text_wrapper = soup.find_all('div',{'class':'text-wrapper style-scope ytd-video-renderer'})

video = []

for link in text_wrapper:
    channel = link.find('div',{'id':'tooltip'}).text.strip()
    th = link.find('a',{'id':'video-title'})
    title = th.get('title')
    href = 'https://www.youtube.com' + th.get('href')
    click = link.find_all('span',{'class':'style-scope ytd-video-meta-block'})[0].text
    date = link.find_all('span',{'class':'style-scope ytd-video-meta-block'})[1].text
    
    video.append([channel, title, href, click, date])
    
df_video = pd.DataFrame(video, columns=['채널명', '영상제목', '영상url', '조회수', '게시일'])
df_video.set_index('채널명', inplace=True)
df_video
# Out:
#                                                                 영상제목  \
# 채널명
# GongbroDesk        파이썬 데이터 분석 - 설치부터 라이브러리 예제까지 (feat. 넘파이, 맷플롯립,...
# 데이터 스테이션           파이썬 판다스로 회사 엑셀데이터 전처리 하는 방법 ! 1탄 (Python / Pan...
# todaycode오늘코드      [1/29] 파이썬 데이터 분석을 위한 Pandas 기초 - 판다스 10분 완성소개...
# Visualising Korea  무슨 분석 툴을 배워야 할까? - 실제 데이터 과학/데이터 분석 업계에서의 R 과 ...
# todaycode오늘코드          [1/5] 파이썬 데이터 분석 - 전국 도시 공원 표준 데이터 불러오기, 요약하기
# 테디노트                                25분만에 끝내는 데이터분석, 머신러닝을 위한 기본 파이썬
# Data Scientist이지영              [통계, 파이썬] 데이터분석 능력 기르기 1. 이건 알고 시작하자.
# Data Scientist이지영     [통계, 파이썬] 데이터분석 능력 기르기 2. 빅데이터의 저주, 파이썬으로 구현하기
# 매일경제 에브리데이         데이터 엔지니어 vs 데이터 분석가 vs 데이터 사이언티스트 연봉 KING 전망 K...
# AI Holic                                         데이터 AI 사이언티스트 하지마세요
# 리뷰BRO              빅데이터 2년공부하고 다른걸로 취업했다! 빅데이터와 취업 리뷰! [ 빅데이터 분석가...
# 나도코딩               파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 ...
# 더블리                [Chapter #2] 2.파이썬 데이터 읽기, 이렇게 쉽게 가능해? 판다스(Pan...
# 동빈나                          Numpy의 기본 사용법 [ Python 데이터 분석과 이미지 처리 ]
# 꽃부리 AI With SJ     머신러닝, 데이터분석 공부 고민만 하는 분께 l 파이썬 공부 이유 l 머신러닝 공부 순서
# 데이터 스테이션           Python Pandas 실무 데이터 분석 1탄 (Series / Dataframe...
# 사이다경제                            [비전공자를 위한] 파이썬 주식데이터 분석 입문 강의 PART1
# 데이터 스테이션           실제 엑셀 데이터 전처리 쉽게하기! (python / data / pandas) #...
# todaycode오늘코드      [1/7] Python, Pandas,  folium으로 스타벅스, 이디야 매장 위...
# 온라인 코딩 스쿨 코드잇                파이썬으로 일상의 데이터를 분석하는 법! 코로나 데이터를 분석해 봐요!
#
#                                                          영상url        조회수  \
# 채널명
# GongbroDesk        https://www.youtube.com/watch?v=8_VWnRvbGPs  조회수 1.7만회
# 데이터 스테이션           https://www.youtube.com/watch?v=3-iwY0_u0VA  조회수 3.9천회
# todaycode오늘코드      https://www.youtube.com/watch?v=lspu830SzC8    조회수 3만회
# Visualising Korea  https://www.youtube.com/watch?v=1e2IjkDYE_8  조회수 2.3만회
# todaycode오늘코드      https://www.youtube.com/watch?v=uJ6QO6jLBWA  조회수 1.2만회
# 테디노트               https://www.youtube.com/watch?v=JoL3ACNDs-I  조회수 9.4천회
# Data Scientist이지영  https://www.youtube.com/watch?v=Dfpi4pAzn78  조회수 7.6천회
# Data Scientist이지영  https://www.youtube.com/watch?v=Ax5ENEciYbE  조회수 2.5천회
# 매일경제 에브리데이         https://www.youtube.com/watch?v=luA8-_BHWRE  조회수 8.1천회
# AI Holic           https://www.youtube.com/watch?v=8mjeJpHtLVQ  조회수 8.7만회
# 리뷰BRO              https://www.youtube.com/watch?v=QtcWFDZGN8M   조회수 11만회
# 나도코딩               https://www.youtube.com/watch?v=kWiCuklohdY  조회수 189만회
# 더블리                https://www.youtube.com/watch?v=RMaZ_uWfrdw    조회수 3천회
# 동빈나                https://www.youtube.com/watch?v=LdoJAC26MIc  조회수 2.7만회
# 꽃부리 AI With SJ     https://www.youtube.com/watch?v=irenjQzqQsw  조회수 5.9천회
# 데이터 스테이션           https://www.youtube.com/watch?v=q4UFSZPjLyo  조회수 6.4천회
# 사이다경제              https://www.youtube.com/watch?v=VmaG6B1tbNU  조회수 2.8천회
# 데이터 스테이션           https://www.youtube.com/watch?v=_bxFs4qTGQQ  조회수 2.2천회
# todaycode오늘코드      https://www.youtube.com/watch?v=PR1WeCdFWvg  조회수 1.7만회
# 온라인 코딩 스쿨 코드잇      https://www.youtube.com/watch?v=oYRETGDVFl4  조회수 1.1천회
#
#                       게시일
# 채널명
# GongbroDesk         6개월 전
# 데이터 스테이션            4개월 전
# todaycode오늘코드        2년 전
# Visualising Korea  11개월 전
# todaycode오늘코드        2년 전
# 테디노트                 1년 전
# Data Scientist이지영  11개월 전
# Data Scientist이지영  11개월 전
# 매일경제 에브리데이          3개월 전
# AI Holic             1년 전
# 리뷰BRO                2년 전
# 나도코딩                 1년 전
# 더블리                  1년 전
# 동빈나                  2년 전
# 꽃부리 AI With SJ      4개월 전
# 데이터 스테이션             1년 전
# 사이다경제               7개월 전
# 데이터 스테이션            4개월 전
# todaycode오늘코드        2년 전
# 온라인 코딩 스쿨 코드잇       8개월 전
